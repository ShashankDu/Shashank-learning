# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''
paper = '''
   _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''
scissors = '''
   _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''
import random
a = input("Enter the number 1,2 or 3 to choose Rock, paper, or Scissors?\n")
input_no = int(a)
random_no = random.randint(1,3)
if input_no == 1:
    print("\nYou chose :\n"+ rock)
    if random_no == 1:
        print("\nComputer Chose:\n"+ rock)
        print("\nIts a tie!\n")
    elif random_no == 2:
        print("\nComputer Chose:\n"+ paper)
        print("\nYou Loose!\n")
    else:
        print("\nComputer chose:\n"+ scissors)
        print("\nYou WIn!\n")
elif input_no == 2:
    print("\nYou Chose:\n" + paper)
    if random_no == 1:
        print("\nComputer Chose:\n" + rock)
        print("\nYou Win!\n")
    elif random_no == 2:
        print("\nComputer Chose:\n" + paper)
        print("\nIts a Tie!\n")
    else:
        print("\nComputer Chose:\n" + scissors)
        print("\nYou Loose!\n")
elif input_no == 3:
    print("\nYou Chose:\n" + scissors)
    if random_no == 1:
        print("\nComputer Chose:\n" + rock)
        print("\nYou Loose!\n")
    elif random_no == 2:
        print("\nComputer Chose:\n" + paper)
        print("\nYou Win!\n")
    else:
        print("\nComputer Chose:\n"+ scissors)
        print("\nIts a Tie!\n")
else:
    print("\nWrong Input\n")
# Out:
# Enter the number 1,2 or 3 to choose Rock, paper, or Scissors?
# 1
#
# You chose :
#
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
#
# Computer Chose:
#
#    _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
#
# You Loose!
